# %%
def som_hits2(x,som):
    
    cmap_aux = plt.cm.YlOrRd
    
    map_size = np.array([som.get_weights().shape[0],som.get_weights().shape[1]])
        
    neur=np.zeros(map_size)
 
    for f in range(np.shape(x)[0]):
        w = som.winner(x[f,:])
        neur[w[1],w[0]]=neur[w[1],w[0]]+1
    mp, mp_aux=grid(tam=map_size,g='hexagonal')
    
   

    for l in range(0,np.shape(mp_aux)[0]-1,4):
        for c in range(np.shape(mp)[1]-1):
            plt.plot([mp_aux[l,c,1],mp_aux[l+1,c+1,1]],[mp_aux[l,c,0],mp_aux[l+1,c+1,0]],color='red')
            plt.plot([mp_aux[l,c,1],mp_aux[l+1,c,1]],[mp_aux[l,c,0],mp_aux[l+1,c,0]],color='black')
        #plt.plot([mp_aux[l,c,1],mp_aux[l+1,c+1,1]],[mp_aux[l,c,0]+(mp_aux[l+5,c,0]-mp_aux[l+1,c,0]),mp_aux[l+1,c+1,0]+(mp_aux[l+5,c,0]-mp_aux[l+1,c,0])],color='red',linewidth=10)
        plt.plot([mp_aux[l,c+1,1],mp_aux[l+1,c+1,1]],[mp_aux[l,c+1,0],mp_aux[l+1,c+1,0]],color='blue')
        plt.plot([-mp_aux[l,0,1],-mp_aux[l+1,0,1]],[mp_aux[l,c,0],mp_aux[l+1,c,0]],color='black')
        plt.plot([mp_aux[l,c,1]+mp_aux[l+1,1,1],mp_aux[l+1,c+1,1]+mp_aux[l+1,1,1]],[mp_aux[l,c,0],mp_aux[l+1,c+1,0]],color='red')
 #   for l in range(0,np.shape(mp_aux)[0]-2,4):
#        for c in range(np.shape(mp)[1]):
#            plt.plot([mp_aux[l+1,c,1],mp_aux[l+2,c,1]],[mp_aux[l+1,c,0],mp_aux[l+2,c,0]],color='cyan')
#        plt.plot([mp_aux[l+1,c,1]+mp_aux[l+1,1,1],mp_aux[l+2,c,1]+mp_aux[l+1,1,1]],[mp_aux[l+1,c,0],mp_aux[l+2,c,0]],color='cyan')
    for l in range(2,np.shape(mp_aux)[0]-1,4):
        for c in range(0,np.shape(mp)[1]-1):
            plt.plot([mp_aux[l,c,1],mp_aux[l+1,c,1]],[mp_aux[l,c,0],mp_aux[l+1,c,0]],color='yellow')
            plt.plot([mp_aux[l,c+1,1],mp_aux[l+1,c,1]],[mp_aux[l,c+1,0],mp_aux[l+1,c,0]],color='green')
        plt.plot([mp_aux[l,c+1,1],mp_aux[l+1,c+1,1]],[mp_aux[l,c+1,0],mp_aux[l+1,c+1,0]],color='red')
        plt.plot([mp_aux[l,0,1],mp_aux[l+1,0,1]-mp_aux[l,1,1]],[mp_aux[l,1,0],mp_aux[l+1,0,0]],color='green')
        plt.plot([mp_aux[l,c+1,1]+mp_aux[l,1,1],mp_aux[l+1,c,1]+mp_aux[l,1,1]],[mp_aux[l,c+1,0],mp_aux[l+1,c,0]],color='green')
#    for c in range(0,np.shape(mp)[1]-1):
#        plt.plot([mp_aux[2,c+1,1],mp_aux[3,c,1]],[mp_aux[2,c+1,0]-(mp_aux[3,0,0]+mp_aux[0,0,0]),mp_aux[3,c,0]-(mp_aux[3,0,0]+mp_aux[0,0,0])],color='green',linewidth=15)
#        plt.plot([mp_aux[2,c,1],mp_aux[3,c,1]],[mp_aux[2,c,0]-(mp_aux[3,0,0]+mp_aux[0,0,0]),mp_aux[3,c,0]-(mp_aux[3,0,0]+mp_aux[0,0,0])],color='yellow')
#    plt.plot([mp_aux[2,0,1],mp_aux[3+1,0,1]-mp_aux[2,1,1]],[mp_aux[2,1,0]-(mp_aux[3,0,0]+mp_aux[0,0,0]),mp_aux[3,0,0]-(mp_aux[3,0,0]+mp_aux[0,0,0])],color='green')
#    plt.plot([mp_aux[2,c+1,1],mp_aux[3,c+1,1]],[mp_aux[2,c+1,0]-(mp_aux[3,0,0]+mp_aux[0,0,0]),mp_aux[3,c+1,0]-(mp_aux[3,0,0]+mp_aux[0,0,0])],color='blue')
    for l in range(2,np.shape(mp_aux)[0]-2,4):
        for c in range(np.shape(mp)[1]):
            plt.plot([mp_aux[l+1,c,1],mp_aux[l+2,c,1]],[mp_aux[l+1,c,0],mp_aux[l+2,c,0]],color='brown')
        plt.plot([-mp_aux[l+1,0,1],-mp_aux[l+2,0,1]],[mp_aux[l+1,c,0],mp_aux[l+2,c,0]],color='brown')
   # for c in range(np.shape(mp)[1]):
   #     plt.plot([mp_aux[l+1,c,1],mp_aux[l+2,c,1]],[mp_aux[l+1,c,0]+(mp_aux[l+5,c,0]-mp_aux[l+1,c,0]),mp_aux[l+2,c,0]+(mp_aux[l+5,c,0]-mp_aux[l+1,c,0])],color='red')
#    for c in range(np.shape(mp)[1]):
  #      plt.plot([mp_aux[l+1,c,1],mp_aux[l+2,c,1]],[mp_aux[0,c,0],-mp_aux[0,c,0]],color='brown')
  #      plt.plot([mp_aux[l+1,c,1],mp_aux[l+2,c,1]],[mp_aux[l,c,0]+mp_aux[4,0,0],mp_aux[l,c,0]+mp_aux[4,0,0]],color='brown')
 
    #plt.plot([-mp_aux[l+1,0,1],-mp_aux[l+2,0,1]],[mp_aux[0,c,0],-mp_aux[0,c,0]],color='brown')
    

  
        
    for l in range(map_size[0]):
        for c in range(map_size[1]):
            
            z=np.array([np.amax(neur),np.amin(neur),neur[l][c]])
            normal = plt.Normalize(z.min(), np.max(neur))
            cmap = cmap_aux(normal(z))
            
            if neur[l][c]==0:
                plt.plot(mp[l,c,1],mp[l,c,0],'h',markersize=20,color='white')
            else:
                plt.plot(mp[l,c,1],mp[l,c,0],'h',markersize=normal(z)[2]*20,color='blue')
    

    
    plt.gca().set_aspect('equal')
    #plt.colorbar(cm.ScalarMappable(norm=normal, cmap=cmap_aux))

    plt.draw()
